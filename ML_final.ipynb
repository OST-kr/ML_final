# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import mnist

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
x_train = x_train/255.0
x_test = x_test/255.0
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
n_input = 784
n_hidden1 = 1024
n_hidden2 = 512
n_hidden3 = 512
n_hidden4 = 512
n_output = 10

mlp = Sequential()
mlp.add(Dense(units = n_hidden1, activation = 'tanh', input_shape=(n_input,), kernel_initializer='random_uniform', bias_initializer='zeros'))
mlp.add(Dense(units = n_hidden2, activation = 'tanh', kernel_initializer='random_uniform', bias_initializer='zeros'))
mlp.add(Dense(units = n_hidden3, activation = 'tanh', kernel_initializer='random_uniform', bias_initializer='zeros'))
mlp.add(Dense(units = n_hidden4, activation = 'tanh', kernel_initializer='random_uniform', bias_initializer='zeros'))
mlp.add(Dense(units = n_output, activation = 'tanh', kernel_initializer='random_uniform', bias_initializer='zeros'))

mlp.compile(loss = 'mse', optimizer = Adam(learning_rate=0.001), metrics = ['accuracy'])
hist = mlp.fit(x_train, y_train, batch_size = 128, epochs = 30, validation_data = (x_test, y_test), verbose = 2)
# Out:
# Epoch 1/30
# 469/469 - 22s - loss: 0.0266 - accuracy: 0.8943 - val_loss: 0.0129 - val_accuracy: 0.9426 - 22s/epoch - 48ms/step
# Epoch 2/30
# 469/469 - 20s - loss: 0.0102 - accuracy: 0.9538 - val_loss: 0.0085 - val_accuracy: 0.9600 - 20s/epoch - 42ms/step
# Epoch 3/30
# 469/469 - 21s - loss: 0.0069 - accuracy: 0.9671 - val_loss: 0.0070 - val_accuracy: 0.9657 - 21s/epoch - 45ms/step
# Epoch 4/30
# 469/469 - 20s - loss: 0.0052 - accuracy: 0.9751 - val_loss: 0.0056 - val_accuracy: 0.9725 - 20s/epoch - 42ms/step
# Epoch 5/30
# 469/469 - 21s - loss: 0.0044 - accuracy: 0.9795 - val_loss: 0.0055 - val_accuracy: 0.9712 - 21s/epoch - 44ms/step
# Epoch 6/30
# 469/469 - 20s - loss: 0.0039 - accuracy: 0.9820 - val_loss: 0.0048 - val_accuracy: 0.9745 - 20s/epoch - 42ms/step
# Epoch 7/30
# 469/469 - 21s - loss: 0.0035 - accuracy: 0.9836 - val_loss: 0.0051 - val_accuracy: 0.9734 - 21s/epoch - 44ms/step
# Epoch 8/30
# 469/469 - 21s - loss: 0.0028 - accuracy: 0.9871 - val_loss: 0.0046 - val_accuracy: 0.9747 - 21s/epoch - 45ms/step
# Epoch 9/30
# 469/469 - 21s - loss: 0.0027 - accuracy: 0.9879 - val_loss: 0.0046 - val_accuracy: 0.9759 - 21s/epoch - 44ms/step
# Epoch 10/30
# 469/469 - 20s - loss: 0.0025 - accuracy: 0.9892 - val_loss: 0.0048 - val_accuracy: 0.9745 - 20s/epoch - 42ms/step
# Epoch 11/30
# 469/469 - 20s - loss: 0.0023 - accuracy: 0.9899 - val_loss: 0.0047 - val_accuracy: 0.9746 - 20s/epoch - 44ms/step
# Epoch 12/30
# 469/469 - 20s - loss: 0.0022 - accuracy: 0.9902 - val_loss: 0.0047 - val_accuracy: 0.9761 - 20s/epoch - 42ms/step
# Epoch 13/30
# 469/469 - 20s - loss: 0.0020 - accuracy: 0.9912 - val_loss: 0.0037 - val_accuracy: 0.9797 - 20s/epoch - 44ms/step
# Epoch 14/30
# 469/469 - 20s - loss: 0.0018 - accuracy: 0.9920 - val_loss: 0.0040 - val_accuracy: 0.9792 - 20s/epoch - 42ms/step
# Epoch 15/30
# 469/469 - 22s - loss: 0.0016 - accuracy: 0.9936 - val_loss: 0.0038 - val_accuracy: 0.9790 - 22s/epoch - 46ms/step
# Epoch 16/30
# 469/469 - 20s - loss: 0.0018 - accuracy: 0.9928 - val_loss: 0.0043 - val_accuracy: 0.9769 - 20s/epoch - 42ms/step
# Epoch 17/30
# 469/469 - 21s - loss: 0.0014 - accuracy: 0.9942 - val_loss: 0.0037 - val_accuracy: 0.9791 - 21s/epoch - 44ms/step
# Epoch 18/30
# 469/469 - 19s - loss: 0.0015 - accuracy: 0.9939 - val_loss: 0.0042 - val_accuracy: 0.9784 - 19s/epoch - 41ms/step
# Epoch 19/30
# 469/469 - 21s - loss: 0.0014 - accuracy: 0.9946 - val_loss: 0.0040 - val_accuracy: 0.9791 - 21s/epoch - 45ms/step
# Epoch 20/30
# 469/469 - 21s - loss: 0.0012 - accuracy: 0.9949 - val_loss: 0.0041 - val_accuracy: 0.9777 - 21s/epoch - 44ms/step
# Epoch 21/30
# 469/469 - 21s - loss: 0.0012 - accuracy: 0.9955 - val_loss: 0.0034 - val_accuracy: 0.9801 - 21s/epoch - 46ms/step
# Epoch 22/30
# 469/469 - 20s - loss: 0.0012 - accuracy: 0.9953 - val_loss: 0.0033 - val_accuracy: 0.9822 - 20s/epoch - 42ms/step
# Epoch 23/30
# 469/469 - 21s - loss: 0.0012 - accuracy: 0.9955 - val_loss: 0.0040 - val_accuracy: 0.9786 - 21s/epoch - 45ms/step
# Epoch 24/30
# 469/469 - 19s - loss: 0.0012 - accuracy: 0.9953 - val_loss: 0.0045 - val_accuracy: 0.9764 - 19s/epoch - 42ms/step
# Epoch 25/30
# 469/469 - 20s - loss: 0.0012 - accuracy: 0.9952 - val_loss: 0.0038 - val_accuracy: 0.9790 - 20s/epoch - 43ms/step
# Epoch 26/30
# 469/469 - 19s - loss: 0.0011 - accuracy: 0.9958 - val_loss: 0.0038 - val_accuracy: 0.9790 - 19s/epoch - 42ms/step
# Epoch 27/30
# 469/469 - 22s - loss: 8.5241e-04 - accuracy: 0.9967 - val_loss: 0.0035 - val_accuracy: 0.9815 - 22s/epoch - 47ms/step
# Epoch 28/30
# 469/469 - 19s - loss: 8.0114e-04 - accuracy: 0.9969 - val_loss: 0.0037 - val_accuracy: 0.9795 - 19s/epoch - 41ms/step
# Epoch 29/30
# 469/469 - 23s - loss: 9.0714e-04 - accuracy: 0.9967 - val_loss: 0.0037 - val_accuracy: 0.9802 - 23s/epoch - 49ms/step
# Epoch 30/30
# 469/469 - 20s - loss: 7.9779e-04 - accuracy: 0.9970 - val_loss: 0.0044 - val_accuracy: 0.9773 - 20s/epoch - 42ms/step

# %%
res = mlp.evaluate(x_test, y_test, verbose = 0)
print("Accuracy is ", res[1]*100)
# Out:
# Accuracy is  97.72999882698059
